# %%
import pandas as pd
import numpy as np
import requests
import re
import time
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

# %%
def import_draft_data_from_PFR_single_year(year, position):
    
    # Get URL for Query
    position_lowercase = position.lower()
    url = f'https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min={year}&year_max={year}&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D={position_lowercase}&conference=any&show=all&order_by=default&order_by_asc=Y'
    print(url)

    # Use the pandas html reader 
    result = pd.read_html(url)
    df = result[0]
    
    # Reset the column names
    super_column_names = [x[0] for x in df.columns]
    actual_column_names = [x[1] for x in df.columns]
    combined_column_names = [x[0]+'_'+x[1] if (x[0][:2] not in ['Un']) else x[1] for x in df.columns]
    df.columns = combined_column_names
    
    # Remove last column which has no info
    df.drop(columns=[df.columns[-1]], inplace=True)
    return df

# %%
def import_draft_data_from_PFR_multiple_years(year_list, position, sleep_time=0.):
    for year in year_list:
        draft_data_here = import_draft_data_from_PFR_single_year(year, position)
        try:
            draft_data = draft_data.append(draft_data_here)
            #print(draft_data.shape)
            #print('Appended!')
        except:
            draft_data = draft_data_here
            #print(draft_data.shape)
            #print('Created!')
        time.sleep(sleep_time) 
    draft_data.reset_index(inplace=True)
    return draft_data

# %%
# Where players were drafted, basic NFL stats, Career AV
# Source: pro-football-refernce
qb_draft_data = import_draft_data_from_PFR_multiple_years(range(2000,2019), 'QB', sleep_time=5.)
# Out:
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2000&year_max=2000&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (12, 26)
# Created!
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2001&year_max=2001&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (23, 26)
# Appended!
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2002&year_max=2002&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (38, 26)
# Appended!
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2003&year_max=2003&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (51, 26)
# Appended!
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2004&year_max=2004&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (68, 26)
# Appended!
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2005&year_max=2005&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (82, 26)
# Appended!
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2006&year_max=2006&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (95, 26)
# Appended!
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2007&year_max=2007&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (106, 26)
# Appended!
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2008&year_max=2008&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (119, 26)
# Appended!
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2009&year_max=2009&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (130, 26)
# Appended!
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2010&year_max=2010&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (143, 26)
# Appended!
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2011&year_max=2011&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (155, 26)
# Appended!
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2012&year_max=2012&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (166, 26)
# Appended!
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2013&year_max=2013&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (177, 26)
# Appended!
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2014&year_max=2014&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (191, 26)
# Appended!
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2015&year_max=2015&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (198, 26)
# Appended!
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2016&year_max=2016&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (213, 26)
# Appended!
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2017&year_max=2017&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (223, 26)
# Appended!
# https://www.pro-football-reference.com/play-index/draft-finder.cgi?request=1&year_min=2018&year_max=2018&draft_slot_min=1&draft_slot_max=500&pick_type=overall&league_id=NFL&pos%5B%5D=qb&conference=any&show=all&order_by=default&order_by_asc=Y
# (236, 26)
# Appended!

# %%
qb_draft_data.columns
# Out:
# Index(['index', 'Rk', 'Year', 'Rnd', 'Pick', 'Player', 'Pos', 'DrAge', 'Tm',
#        'From', 'To', 'Misc_AP1', 'Misc_PB', 'St', 'CarAV', 'Games_G',
#        'Games_GS', 'Passing_QBrec', 'Passing_Cmp', 'Passing_Att',
#        'Passing_Yds', 'Passing_TD', 'Passing_Int', 'Rushing_Att',
#        'Rushing_Yds', 'Rushing_TD', 'College/Univ'],
#       dtype='object')

# %%
qb_draft_data['Passing_Yds_per_Att'] = qb_draft_data['Passing_Yds'] / qb_draft_data['Passing_Att']

# %%
qb_draft_data['Passing_Yds_per_Game'] = qb_draft_data['Passing_Yds'] / qb_draft_data['Games_G']

# %%
qb_draft_data['CarAV/Start'] = qb_draft_data['CarAV'] / qb_draft_data['Games_GS']

# %%
qb_draft_data['CarAV/Game'] = qb_draft_data['CarAV'] / qb_draft_data['Games_G']

# %%
qb_draft_data[['Rk', 'Year','Pick','Player','Games_G','Passing_Yds','Passing_Yds_per_Att','Passing_Yds_per_Game','CarAV','CarAV/Game']].sort_values(by='Passing_Yds_per_Game', ascending=False)
# Out:
#      Rk  Year  Pick                Player  Games_G  Passing_Yds  \
# 214   2  2017    10       Patrick Mahomes     17.0       5381.0
# 13    2  2001    32            Drew Brees    264.0      74437.0
# 155   1  2012     1           Andrew Luck     86.0      23671.0
# 119   1  2009     1      Matthew Stafford    141.0      38526.0
# 106   1  2008     3             Matt Ryan    174.0      46720.0
# 223   1  2018     1        Baker Mayfield     14.0       3725.0
# 162   8  2012   102          Kirk Cousins     78.0      20504.0
# 6     7  2000   199             Tom Brady    269.0      70514.0
# 191   1  2015     1        Jameis Winston     56.0      14628.0
# 69    2  2005    24         Aaron Rodgers    165.0      42944.0
# 53    3  2004    11    Ben Roethlisberger    216.0      56194.0
# 52    2  2004     4         Philip Rivers    212.0      54656.0
# 215   3  2017    12        Deshaun Watson     23.0       5864.0
# 38    1  2003     1         Carson Palmer    182.0      46247.0
# 199   2  2016     2          Carson Wentz     40.0      10152.0
# 198   1  2016     1            Jared Goff     38.0       9581.0
# 51    1  2004     1           Eli Manning    232.0      55981.0
# 180   4  2014    36            Derek Carr     78.0      18739.0
# 4     5  2000   168           Marc Bulger     96.0      22814.0
# 177   1  2014     3         Blake Bortles     75.0      17646.0
# 107   2  2008    18            Joe Flacco    163.0      38245.0
# 130   1  2010     1          Sam Bradford     83.0      19449.0
# 147   5  2011    35           Andy Dalton    120.0      28100.0
# 157   3  2012     8        Ryan Tannehill     88.0      20434.0
# 143   1  2011     1            Cam Newton    123.0      28469.0
# 84    3  2006    11            Jay Cutler    153.0      35133.0
# 160   6  2012    75        Russell Wilson    112.0      25624.0
# 205   8  2016   135          Dak Prescott     48.0      10876.0
# 121   3  2009    17          Josh Freeman     62.0      13873.0
# 224   2  2018     3           Sam Darnold     13.0       2865.0
# ..   ..   ...   ...                   ...      ...          ...
# 125   7  2009   171            Nate Davis      NaN          NaN
# 127   9  2009   178             Mike Teel      NaN          NaN
# 136   7  2010   168     Jonathan Crompton      NaN          NaN
# 138   9  2010   181          Dan LeFevour      NaN          NaN
# 141  12  2010   239         Sean Canfield      NaN          NaN
# 142  13  2010   250          Zac Robinson      NaN          NaN
# 150   8  2011   135          Ricky Stanzi      0.0          NaN
# 152  10  2011   160        Nathan Enderle      NaN          NaN
# 164  10  2012   243          B.J. Coleman      NaN          NaN
# 165  11  2012   253      Chandler Harnish      0.0          NaN
# 171   6  2013   112          Tyler Wilson      NaN          NaN
# 173   8  2013   221         Brad Sorensen      0.0          NaN
# 174   9  2013   234            Zac Dysert      0.0          NaN
# 184   8  2014   163          Aaron Murray      0.0          NaN
# 188  12  2014   194         Keith Wenning      0.0          NaN
# 189  13  2014   213             Tajh Boyd      NaN          NaN
# 193   3  2015    75       Garrett Grayson      1.0          NaN
# 201   4  2016    51  Christian Hackenberg      NaN          NaN
# 210  13  2016   201         Brandon Allen      NaN          NaN
# 212  15  2016   223       Brandon Doughty      NaN          NaN
# 217   5  2017    87            Davis Webb      NaN          NaN
# 221   9  2017   215            Brad Kaaya      NaN          NaN
# 222  10  2017   253            Chad Kelly      1.0          NaN
# 228   6  2018    76         Mason Rudolph      NaN          NaN
# 230   8  2018   171            Mike White      NaN          NaN
# 231   9  2018   199             Luke Falk      NaN          NaN
# 232  10  2018   203            Tanner Lee      NaN          NaN
# 233  11  2018   219          Danny Etling      NaN          NaN
# 234  12  2018   220          Alex McGough      NaN          NaN
# 235  13  2018   249        Logan Woodside      NaN          NaN
#
#      Passing_Yds_per_Att  Passing_Yds_per_Game  CarAV  CarAV/Game
# 214             8.749593            316.529412   23.0    1.352941
# 13              7.608811            281.958333  164.0    0.621212
# 155             7.194833            275.244186   71.0    0.825581
# 119             7.127845            273.234043   91.0    0.645390
# 106             7.534269            268.505747  129.0    0.741379
# 223             7.664609            266.071429   10.0    0.714286
# 162             7.588453            262.871795   51.0    0.653846
# 6               7.521493            262.133829  175.0    0.650558
# 191             7.610822            261.214286   41.0    0.732143
# 69              7.819374            260.266667  135.0    0.818182
# 53              7.839565            260.157407  125.0    0.578704
# 52              7.808000            257.811321  140.0    0.660377
# 215             8.270804            254.956522   23.0    1.000000
# 38              7.332646            254.104396  108.0    0.593407
# 199             7.011050            253.800000   32.0    0.800000
# 198             7.707965            252.131579   30.0    0.789474
# 51              7.022203            241.297414  117.0    0.504310
# 180             6.692500            240.243590   46.0    0.589744
# 4               7.194576            237.645833   57.0    0.593750
# 177             6.704407            235.280000   44.0    0.586667
# 107             6.745150            234.631902   89.0    0.546012
# 130             6.555106            234.325301   44.0    0.530120
# 147             7.166539            234.166667   77.0    0.641667
# 157             7.019581            232.204545   54.0    0.613636
# 143             7.316628            231.455285  103.0    0.837398
# 84              7.140854            229.627451   87.0    0.568627
# 160             7.857712            228.785714   98.0    0.875000
# 205             7.373559            226.583333   42.0    0.875000
# 121             6.773926            223.758065   38.0    0.612903
# 224             6.920290            220.384615    7.0    0.538462
# ..                   ...                   ...    ...         ...
# 125                  NaN                   NaN    NaN         NaN
# 127                  NaN                   NaN    NaN         NaN
# 136                  NaN                   NaN    NaN         NaN
# 138                  NaN                   NaN    NaN         NaN
# 141                  NaN                   NaN    NaN         NaN
# 142                  NaN                   NaN    0.0         NaN
# 150                  NaN                   NaN    0.0         NaN
# 152                  NaN                   NaN    NaN         NaN
# 164                  NaN                   NaN    0.0         NaN
# 165                  NaN                   NaN    0.0         NaN
# 171                  NaN                   NaN    NaN         NaN
# 173                  NaN                   NaN    0.0         NaN
# 174                  NaN                   NaN    0.0         NaN
# 184                  NaN                   NaN    0.0         NaN
# 188                  NaN                   NaN    0.0         NaN
# 189                  NaN                   NaN    NaN         NaN
# 193                  NaN                   NaN    0.0    0.000000
# 201                  NaN                   NaN    NaN         NaN
# 210                  NaN                   NaN    NaN         NaN
# 212                  NaN                   NaN    NaN         NaN
# 217                  NaN                   NaN    NaN         NaN
# 221                  NaN                   NaN    NaN         NaN
# 222                  NaN                   NaN    0.0    0.000000
# 228                  NaN                   NaN    NaN         NaN
# 230                  NaN                   NaN    NaN         NaN
# 231                  NaN                   NaN    NaN         NaN
# 232                  NaN                   NaN    NaN         NaN
# 233                  NaN                   NaN    NaN         NaN
# 234                  NaN                   NaN    NaN         NaN
# 235                  NaN                   NaN    NaN         NaN
#
# [236 rows x 10 columns]

# %%
# %matplotlib notebook
# %matplotlib notebook
qb_draft_data.plot(kind='scatter',x='Pick', y='CarAV', title='CarAV vs Pick', logx=False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
qb_draft_data.plot(kind='scatter',x='Pick', y='Passing_Yds', title='Career Passing Yds vs Pick', logx=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
qb_draft_data.plot(kind='scatter',x='Pick', y='Passing_Yds_per_Game', title='Passing Yds per Game vs Pick')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.scatter(qb_draft_data['Year'].astype(int), qb_draft_data['CarAV'], c=qb_draft_data['CarAV/Game'], s=50)
plt.colorbar()
plt.title('Career Approximate Value vs Year Drafted')
plt.xlim([2000-1,2020])
plt.xticks(range(2000,2025,5))
plt.xlabel('Year Drafted')
plt.ylabel('Career Approximate Value')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.scatter(qb_draft_data['Year'], qb_draft_data['Passing_Yds_per_Game'], c=np.log(qb_draft_data['Pick']), s=10)
plt.title('Passing Yards per Game vs Year Drafted')
cbar_labels = np.array([1,2,5,10,20,50,100,200])
cbar = plt.colorbar(ticks=np.log(cbar_labels))
cbar.set_label('log(Pick)')
cbar.ax.set_yticklabels(cbar_labels) 
plt.xlim([2000-1,2020])
plt.xticks(range(2000,2025,5))
plt.xlabel('Year Drafted')
plt.ylabel('Passing Yards/Game')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
